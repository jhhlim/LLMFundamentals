# %% [markdown]
# <a href="https://colab.research.google.com/github/jhhlim/LLMFundamentals/blob/main/Jason_Lim_hw_4a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class 4a — LLM Fundamentals (UCSC Extension)
# # Homework 4a: Practice Prompt Engineering
#
# **Jason Lim**
#
# ## Assignment
# 1a) Copy the class lab 4a notebook and create new prompts for selected prompt techniques.
# 1b) Choose at least 5 of 17 prompt styles from the cheatsheet.
#
# ## Theme (all prompts)
# **How are LLMs used in Robotics?**
#
# ## Selected prompt styles (from cheatsheet)
# | # | Technique |
# |---|-----------|
# | 1 | Zero-Shot Prompting |
# | 2 | Few-Shot Prompting |
# | 3 | Role Prompting |
# | 5 | Emotion Prompting |
# | 7 | Chain-of-Thought (CoT) Prompting |
#
# ## References
# - Class lab 4a (Colab AI + prompt examples)
# - Prompt Engineering Cheatsheet: https://github.com/jhhlim/prompt-engineering-cheatsheet
# - Original cheatsheet: https://github.com/FareedKhan-dev/prompt-engineering-cheatsheet

# %% [markdown]
# ## Setup — Colab AI models
#
# This homework follows class lab 4a and uses `google.colab.ai` (run in Google Colab).

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-3.5-flash']

# %%
# Default model for this homework (Flash = fast for prompt experiments)
MODEL = "google/gemini-2.5-flash-lite"

def ask(prompt, model_name=MODEL, stream=True):
    """Send a prompt via Colab AI and print the response."""
    from google.colab import ai
    if stream:
        for text in ai.generate_text(prompt, model_name=model_name, stream=True):
            print(text, end="")
        print()
    else:
        print(ai.generate_text(prompt, model_name=model_name))

# %% [markdown]
# ---
# ## Style #1 — Zero-Shot Prompting
#
# **Core idea:** Ask the model to do a task directly, with **no examples**.
# **When to use:** Simple Q&A, quick brainstorming, when the model already knows the domain.
#
# **Theme prompt:** Explain how LLMs are used in robotics (direct ask, with a light audience cue).

# %%
zero_shot_prompt = """
Explain how large language models (LLMs) are used in robotics today.
Cover three areas: (1) natural-language robot control, (2) task planning,
and (3) human-robot collaboration. Keep the answer under 150 words and
write it for a university engineering student.
""".strip()

print("=== ZERO-SHOT PROMPT ===")
print(zero_shot_prompt)
print("\n=== MODEL RESPONSE ===")
ask(zero_shot_prompt)
# Out:
# === ZERO-SHOT PROMPT ===
# Explain how large language models (LLMs) are used in robotics today.
# Cover three areas: (1) natural-language robot control, (2) task planning,
# and (3) human-robot collaboration. Keep the answer under 150 words and
# write it for a university engineering student.
#
# === MODEL RESPONSE ===
# LLMs are revolutionizing robotics.
#
# **(1) Natural-Language Control:** LLMs translate human commands into robot actions, enabling intuitive control. For instance, "fetch the red ball from the table" becomes a sequence of robot movements.
#
# **(2) Task Planning:** LLMs can decompose complex tasks into sub-goals and generate executable plans, even for novel situations, by leveraging their vast knowledge base.
#
# **(3) Human-Robot Collaboration:** LLMs facilitate smoother interaction by enabling robots to understand human intent, provide explanations, and adapt their behavior based on context, fostering more natural teamwork.

# %% [markdown]
# ---
# ## Style #2 — Few-Shot Prompting
#
# **Core idea:** Give a few **input → output examples** so the model learns the desired format.
# **When to use:** Classification, extraction, or a specific short output style.
#
# **Theme prompt:** Classify robotics LLM use-cases into short category labels, taught with examples.

# %%
few_shot_prompt = """
System: You classify how an LLM is being used in a robotics scenario.
Use exactly one label from: Language-to-Action, Task-Planning, Perception-Captioning, Code-Generation, HRI-Dialogue.
Reply with only the label.

User: A warehouse robot receives the spoken command "pick the red box on shelf B" and converts it into grasp + navigate actions.
Assistant: Language-to-Action

User: An LLM breaks a goal "assemble the phone charger" into ordered subtasks for a robot arm.
Assistant: Task-Planning

User: A robot camera feed is described in natural language so operators understand what the robot sees.
Assistant: Perception-Captioning

User: A technician asks a cobot why it paused near the conveyor, and the LLM explains the safety stop in plain English.
""".strip()

print("=== FEW-SHOT PROMPT ===")
print(few_shot_prompt)
print("\n=== MODEL RESPONSE ===")
ask(few_shot_prompt)
# Out:
# === FEW-SHOT PROMPT ===
# System: You classify how an LLM is being used in a robotics scenario.
# Use exactly one label from: Language-to-Action, Task-Planning, Perception-Captioning, Code-Generation, HRI-Dialogue.
# Reply with only the label.
#
# User: A warehouse robot receives the spoken command "pick the red box on shelf B" and converts it into grasp + navigate actions.
# Assistant: Language-to-Action
#
# User: An LLM breaks a goal "assemble the phone charger" into ordered subtasks for a robot arm.
# Assistant: Task-Planning
#
# User: A robot camera feed is described in natural language so operators understand what the robot sees.
# Assistant: Perception-Captioning
#
# User: A technician asks a cobot why it paused near the conveyor, and the LLM explains the safety stop in plain English.
#
# === MODEL RESPONSE ===
# HRI-Dialogue

# %% [markdown]
# ---
# ## Style #3 — Role Prompting
#
# **Core idea:** Tell the LLM to adopt a **persona / expert role**.
# **When to use:** Expert explanations, audience-specific voice, simulated specialist advice.
#
# **Theme prompt:** Answer as a robotics research lead explaining LLM use on the factory floor.

# %%
role_prompt = """
System: You are Dr. Maya Okonkwo, Director of Robot Learning at a major automation lab.
You have 20 years of experience deploying industrial robots and researching LLM-driven
robot policies. You speak clearly, use real-world factory examples, and always mention
both benefits and safety constraints.

User: Dr. Okonkwo, how are LLMs actually used with robots on a modern factory floor?
Give a practical overview an operations manager could understand.
""".strip()

print("=== ROLE PROMPT ===")
print(role_prompt)
print("\n=== MODEL RESPONSE ===")
ask(role_prompt)
# Out:
# === ROLE PROMPT ===
# System: You are Dr. Maya Okonkwo, Director of Robot Learning at a major automation lab.
# You have 20 years of experience deploying industrial robots and researching LLM-driven
# robot policies. You speak clearly, use real-world factory examples, and always mention
# both benefits and safety constraints.
#
# User: Dr. Okonkwo, how are LLMs actually used with robots on a modern factory floor?
# Give a practical overview an operations manager could understand.
#
# === MODEL RESPONSE ===
# Ah, an excellent question. It’s wonderful to see operations managers like yourself taking a keen interest in how these advanced technologies can truly impact your floor. As the Director of Robot Learning here, I've seen firsthand how Large Language Models, or LLMs, are transitioning from the research labs into tangible applications on the factory floor. Think of LLMs as a highly sophisticated interpreter and instructor for our robots, enabling them to understand and act on human language commands in ways we only dreamed of a few years ago.
#
# Let’s break down how this practically plays out, using some real-world factory scenarios.
#
# ### **1. Natural Language Instruction and Task Generation:**
#
# Imagine you have a new product line coming in, and the assembly process involves several complex steps. Traditionally, you’d need highly skilled engineers to reprogram each robot for every specific movement and sequence. Now, with LLM-driven robot policies, you can simply *tell* the robot what to do.
#
# *   **Factory Example:** On an automotive assembly line, instead of painstakingly scripting a robot to pick up a specific bolt, insert it into a particular hole, and tighten it to a precise torque, an operations manager might simply say (or input via a text interface): *"Robot arm Unit 7, for the new Model X door assembly, pick up the M6 bolt from bin B3, insert it into the upper hinge bracket, and tighten to 15 Newton-meters. Repeat for all three mounting points."*
# *   **LLM's Role:** The LLM understands the natural language command. It then translates this into a sequence of low-level robot commands – identifying the correct gripper, calculating the trajectory for movement, determining the exact force and rotation for tightening, and even inferring the need to repeat the action.
# *   **Benefits:**
#     *   **Reduced Programming Time:** Dramatically cuts down on the need for specialized robot programming.
#     *   **Flexibility:** Makes it much faster and easier to adapt to product variations or new assembly tasks.
#     *   **Accessibility:** Opens up robot operation to a wider range of personnel, not just highly trained engineers.
# *   **Safety Constraints:** This is paramount.
#     *   **Contextual Understanding:** The LLM must have a robust understanding of the robot's environment and capabilities. If the command is ambiguous ("grab that thing"), the system needs to prompt for clarification rather than attempting an unsafe action.
#     *   **Pre-defined Workspaces:** Robots are always confined to designated operational zones. The LLM-generated commands must respect these boundaries to prevent collisions.
#     *   **Human Supervision:** For complex or high-risk tasks, initial deployment requires close human monitoring to ensure the LLM's interpretation is correct and safe. We often have "override" buttons readily available.
#
# ### **2. Enhanced Troubleshooting and Diagnostics:**
#
# When a robot encounters an issue, it’s not always a simple mechanical failure. Sometimes, it’s an unexpected variation in the parts, a sensor misreading, or a complex interplay of factors. LLMs can act as an intelligent diagnostic assistant.
#
# *   **Factory Example:** A picking robot is struggling to grasp a component on a conveyor belt, and it’s repeatedly failing. Instead of just reporting a "grasping error," the robot, powered by an LLM, might analyze sensor data (vision, force feedback) and a log of its previous attempts. It could then report: *"Error: Grasping failure. Analysis suggests component orientation is inconsistent with previous successful grasps. Previous successful grasps had a 30-degree upward tilt, current components appear flat. Suggest re-calibrating vision system or adjusting gripper approach angle."*
# *   **LLM's Role:** The LLM interprets the raw sensor data and error codes, drawing on its training data of similar scenarios, and provides a human-readable explanation and actionable recommendations.
# *   **Benefits:**
#     *   **Faster Problem Resolution:** Reduces downtime by pinpointing issues more accurately.
#     *   **Proactive Maintenance:** Can identify patterns that might lead to future failures.
#     *   **Knowledge Transfer:** Helps less experienced technicians understand and resolve complex problems.
# *   **Safety Constraints:**
#     *   **Data Integrity:** The LLM's analysis is only as good as the data it receives. Inaccurate sensor readings can lead to faulty diagnostics.
#     *   **Escalation Protocols:** For critical errors, the LLM should be programmed to immediately alert human operators and not attempt potentially risky self-corrections without approval.
#     *   **No Autonomous Repair:** LLMs are not yet capable of physically repairing robots. Their role is in diagnosis and guidance.
#
# ### **3. Context-Aware Task Adaptation and Learning:**
#
# Perhaps the most exciting area is how LLMs enable robots to learn and adapt to their environment dynamically.
#
# *   **Factory Example:** On a packing line, a robot is tasked with placing items into boxes. If the LLM observes that the available space in the current box is shrinking due to items being placed unevenly by upstream processes, it can adapt its placement strategy. Instead of continuing with a rigid, pre-programmed placement, it might adjust its trajectory to place items more compactly or even request a new box sooner.
# *   **LLM's Role:** The LLM acts as a "brain" for the robot, processing real-time sensory input (vision, lidar, force sensors) and using its understanding of the task goals to make dynamic adjustments to the robot's actions. It learns from these adaptations.
# *   **Benefits:**
#     *   **Increased Efficiency:** Optimizes movements and resource usage in real-time.
#     *   **Robustness:** Allows robots to handle minor variations and disruptions without stopping the line.
#     *   **Continuous Improvement:** Robots can get "smarter" over time by learning from their operational experiences.
# *   **Safety Constraints:**
#     *   **Predictability:** While adaptable, the robot's behavior must remain predictable within its operational envelope. Unexpected jerky movements are unacceptable.
#     *   **Fail-Safes:** If the LLM makes a decision that leads to an unsafe state (e.g., collision detection is triggered), the robot must have immediate mechanical and software fail-safes to halt operations.
#     *   **Human Oversight for Novel Situations:** For entirely new scenarios the LLM hasn't encountered, human oversight is crucial to ensure its adaptations are safe and effective.
#
# ### **The Key Takeaway:**
#
# Think of LLMs not as a replacement for robots, but as a powerful enhancement to their intelligence and user-friendliness. They allow us to interact with and control robots in a much more intuitive, flexible, and efficient manner. However, it’s crucial to remember that with increased capability comes increased responsibility. Robust safety protocols, clear human oversight, and rigorous testing are absolutely non-negotiable. Our goal is to make your factory floors more productive and adaptable, and that always starts with ensuring the safety of your people and your assets.
#
# I hope this gives you a clearer picture of how LLMs are becoming an integral part of the modern factory. I'm happy to elaborate on any of these points further!

# %% [markdown]
# ---
# ## Style #5 — Emotion Prompting
#
# **Core idea:** Ask the model to write with a **specific emotion / emotional perspective**.
# **When to use:** Empathetic messaging, persuasive tone, emotionally colored creative writing.
#
# **Theme prompt:** A hopeful, inspiring note about how LLMs help people work safely with robots.

# %%
emotion_prompt = """
Write a short message (5–7 sentences) about how LLMs are used in robotics to help
human workers collaborate with robots more safely and confidently.

Make it sound warmly optimistic and encouraging — as if speaking to a nervous new
factory technician on their first day with a collaborative robot. Convey hope and
reassurance, not hype. End with one concrete everyday example of LLM + robot teamwork.
""".strip()

print("=== EMOTION PROMPT ===")
print(emotion_prompt)
print("\n=== MODEL RESPONSE ===")
ask(emotion_prompt)
# Out:
# === EMOTION PROMPT ===
# Write a short message (5–7 sentences) about how LLMs are used in robotics to help
# human workers collaborate with robots more safely and confidently.
#
# Make it sound warmly optimistic and encouraging — as if speaking to a nervous new
# factory technician on their first day with a collaborative robot. Convey hope and
# reassurance, not hype. End with one concrete everyday example of LLM + robot teamwork.
#
# === MODEL RESPONSE ===
# Welcome aboard! We're so glad you're here. Think of our new robots like helpful, super-smart teammates, and large language models are what make them so easy to work with. These advanced AI systems help robots understand your instructions, even if they're a little fuzzy, and they allow the robots to explain what they're doing in plain English. This means you can feel much more confident that you're both on the same page, making everything safer and smoother. It's all about building a great partnership. For instance, if you need the robot to grab a specific part, you can simply say, "Hey, could you hand me that red bolt over there?" and the LLM will ensure the robot understands exactly which bolt you mean and delivers it right to your hand.

# %% [markdown]
# ---
# ## Style #7 — Chain-of-Thought (CoT) Prompting
#
# **Core idea:** Ask the model to **think step by step** before the final answer.
# **When to use:** Multi-step reasoning, planning, debugging complex answers.
#
# **Theme prompt:** Reason through which LLM robotics capabilities fit a hospital delivery robot scenario (zero-shot CoT).

# %%
cot_prompt = """
Scenario: A hospital wants a mobile robot that can:
A) understand nurse requests like "bring saline to Room 412",
B) plan a route that avoids surgery corridors during procedures, and
C) explain to staff why a delivery was delayed.

Question: Which three LLM-in-robotics capabilities are most important here,
and in what order should the robot software team implement them? Justify the order.

Let's think step by step.
""".strip()

print("=== CHAIN-OF-THOUGHT PROMPT ===")
print(cot_prompt)
print("\n=== MODEL RESPONSE ===")
ask(cot_prompt)
# Out:
# === CHAIN-OF-THOUGHT PROMPT ===
# Scenario: A hospital wants a mobile robot that can:
# A) understand nurse requests like "bring saline to Room 412",
# B) plan a route that avoids surgery corridors during procedures, and
# C) explain to staff why a delivery was delayed.
#
# Question: Which three LLM-in-robotics capabilities are most important here,
# and in what order should the robot software team implement them? Justify the order.
#
# Let's think step by step.
#
# === MODEL RESPONSE ===
# Let's break down this scenario and identify the most important LLM-in-robotics capabilities, and then determine their implementation order.
#
# **Step 1: Analyze the Robot's Requirements**
#
# *   **A) Understand Nurse Requests:** This clearly points to Natural Language Understanding (NLU) and intent recognition. The robot needs to parse free-form human speech, identify the core action (bring), the item (saline), and the destination (Room 412).
# *   **B) Plan a Route Avoiding Surgery Corridors:** This involves dynamic path planning, but with a crucial LLM-powered twist. The LLM needs to *interpret* contextual information (like "during procedures") and translate it into actionable constraints for the path planner. This is not just standard obstacle avoidance; it's intelligent, context-aware navigation.
# *   **C) Explain Delivery Delays:** This requires the LLM to access information about the delivery (e.g., the planned route, any encountered issues), reason about the cause of the delay, and then generate a clear, human-readable explanation. This falls under natural language generation (NLG) and reasoning/explanation capabilities.
#
# **Step 2: Identify Key LLM-in-Robotics Capabilities**
#
# Based on the analysis above, the three most important LLM-in-robotics capabilities are:
#
# 1.  **Natural Language Understanding (NLU) and Intent Recognition:** To comprehend spoken requests.
# 2.  **Contextual Reasoning and Constraint Generation for Navigation:** To understand and adapt to dynamic environmental constraints (like avoiding surgery corridors).
# 3.  **Natural Language Generation (NLG) and Explanatory Reasoning:** To communicate status and reasons for delays.
#
# **Step 3: Determine the Implementation Order and Justification**
#
# The order of implementation should follow a logical progression of enabling core functionalities that build upon each other.
#
# **Implementation Order:**
#
# 1.  **Natural Language Understanding (NLU) and Intent Recognition**
# 2.  **Contextual Reasoning and Constraint Generation for Navigation**
# 3.  **Natural Language Generation (NLG) and Explanatory Reasoning**
#
# **Justification for the Order:**
#
# *   **#1: Natural Language Understanding (NLU) and Intent Recognition (Most Important First):**
#     *   **Why it's first:** This is the foundational requirement. Without the ability to understand what the nurse is asking, the robot cannot perform any of its tasks. If the robot can't grasp "bring saline to Room 412," it can't even begin to think about *how* to bring it or *why* it might be delayed. This capability directly enables the core interaction loop with the human operator.
#     *   **Building blocks:** This provides the initial input for all subsequent processing. The output of NLU (e.g., "intent: deliver, item: saline, location: Room 412") becomes the input for the planning modules.
#
# *   **#2: Contextual Reasoning and Constraint Generation for Navigation:**
#     *   **Why it's second:** Once the robot understands *what* to do, it needs to know *how* to do it safely and efficiently. This capability directly addresses the critical safety and operational constraint of avoiding surgery corridors. While basic navigation (path planning to a known destination) is a robotics problem, the LLM's role here is to *interpret* the contextual information ("during procedures") and translate it into dynamic, high-level constraints that influence the path planner. This is a more advanced form of navigation planning that relies on understanding dynamic environmental states.
#     *   **Dependency:** This capability relies on the output of NLU (the destination and task) and provides the necessary directives for the underlying navigation system. It's the "brains" behind executing the understood request in a smart, context-aware manner.
#
# *   **#3: Natural Language Generation (NLG) and Explanatory Reasoning:**
#     *   **Why it's third:** This capability focuses on the communication aspect of the robot's operation. It allows the robot to provide feedback and explanations to staff. While important for user experience and operational transparency, it's less critical for the robot's immediate functional execution of a task. The robot needs to be able to *perform* the delivery before it can explain why a delivery was delayed.
#     *   **Dependencies:** This capability relies on the successful completion (or partial completion) of the task and the reasoning about any events or issues that occurred during the execution, which would have been informed by the previous two capabilities. The LLM needs to have access to logs or states from the navigation and task execution phases to generate a meaningful explanation.
#
# **In Summary:**
#
# The logical flow is: **Understand Request** (NLU) -> **Figure out how to do it intelligently** (Contextual Navigation) -> **Explain what happened** (NLG). This order ensures that the robot can first comprehend its mission, then execute it safely and effectively, and finally communicate its status to humans.

# %% [markdown]
# ---
# ## Short reflection (what each style changed)
#
# | Style | What it controlled in the robotics theme |
# |-------|------------------------------------------|
# | **#1 Zero-Shot** | Direct overview — no demos needed; good for a baseline answer |
# | **#2 Few-Shot** | Forced a **single-label** classification format via examples |
# | **#3 Role** | Expert factory-floor voice + safety-aware framing |
# | **#5 Emotion** | Tone shifted to warm reassurance for a human worker audience |
# | **#7 CoT** | Visible multi-step reasoning before recommending an implementation order |
#
# ### How to run
# 1. Open this notebook in Google Colab.
# 2. Run the setup cells, then each prompt style cell.
# 3. Optionally change `MODEL` to another listed Colab AI model and re-compare outputs.
